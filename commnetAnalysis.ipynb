# %% [markdown]
# <a href="https://colab.research.google.com/github/optimistic-coder/web-scrapping/blob/main/commnetAnalysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import os

# Import functions for data preprocessing & data preparation
from sklearn.preprocessing import LabelEncoder
from sklearn.utils import resample
from sklearn.feature_extraction.text import CountVectorizer
from nltk.sentiment.vader import SentimentIntensityAnalyzer

from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
from nltk.stem import PorterStemmer, LancasterStemmer
from nltk.stem.snowball import SnowballStemmer
from nltk.corpus import stopwords
from nltk.corpus import wordnet
import string
from string import punctuation
import nltk
import re

# %%
data = pd.read_csv('/content/UScomments.csv', error_bad_lines=False)
data.columns
data1=data.drop(['video_id','likes','replies'],axis=1)
data1
# Out:
# <ipython-input-8-977e7138bfd9>:1: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   data = pd.read_csv('/content/UScomments.csv', error_bad_lines=False)
# Skipping line 41589: expected 4 fields, saw 11
# Skipping line 51628: expected 4 fields, saw 7
# Skipping line 114465: expected 4 fields, saw 5
#
# Skipping line 142496: expected 4 fields, saw 8
# Skipping line 189732: expected 4 fields, saw 6
# Skipping line 245218: expected 4 fields, saw 7
#
# Skipping line 388430: expected 4 fields, saw 5
#
# <ipython-input-8-977e7138bfd9>:1: DtypeWarning: Columns (2,3) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv('/content/UScomments.csv', error_bad_lines=False)
#                                              comment_text
# 0                       Logan Paul it's yo big day ‼️‼️‼️
# 1       I've been following you from the start of your...
# ...

# %%
import nltk
import pandas as pd
from nltk.sentiment.vader import SentimentIntensityAnalyzer

# Download the VADER lexicon and other required resources
nltk.download('vader_lexicon')

# Load your dataset (replace 'your_dataset.csv' with your actual file)
data = pd.read_csv('/content/UScomments.csv', error_bad_lines=False)

# Create an instance of the SentimentIntensityAnalyzer
sid = SentimentIntensityAnalyzer()

# Perform sentiment analysis on each comment in the dataset
sentiments = []

for comment in data['comment_text']:
    if isinstance(comment, float):  # Check if the comment is a float
        comment = str(comment)       # Convert float to string
    sentiment_scores = sid.polarity_scores(comment)

    if sentiment_scores['compound'] >= 0.05:
        sentiment = 'positive'
    elif sentiment_scores['compound'] <= -0.05:
        sentiment = 'negative'
    else:
        sentiment = 'neutral'

    sentiments.append(sentiment)
# Out:
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# <ipython-input-17-d0a080782f71>:9: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   data = pd.read_csv('/content/UScomments.csv', error_bad_lines=False)
# Skipping line 41589: expected 4 fields, saw 11
# Skipping line 51628: expected 4 fields, saw 7
# Skipping line 114465: expected 4 fields, saw 5
#
# Skipping line 142496: expected 4 fields, saw 8
# Skipping line 189732: expected 4 fields, saw 6
# Skipping line 245218: expected 4 fields, saw 7
#
# Skipping line 388430: expected 4 fields, saw 5
#
# <ipython-input-17-d0a080782f71>:9: DtypeWarning: Columns (2,3) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv('/content/UScomments.csv', error_bad_lines=False)
# ...

# %%
# Add the 'sentiment' column to the dataset
data['sentiment'] = sentiments

# Print a sample of the dataset with sentiments
print(data[['comment_text', 'sentiment']].head())

# Test the sentiment analysis on sample comments
sample_comments = ["I love this product!", "This is terrible.", "It's okay, I guess."]
sample_sentiments = []

for comment in sample_comments:
    sentiment_scores = sid.polarity_scores(comment)

    if sentiment_scores['compound'] >= 0.05:
        sentiment = 'positive'
    elif sentiment_scores['compound'] <= -0.05:
        sentiment = 'negative'
    else:
        sentiment = 'neutral'

    sample_sentiments.append(sentiment)

# Print the sentiments of the sample comments
print("\nSample Comment Sentiments:")
for i, comment in enumerate(sample_comments):
    print(f"Comment: '{comment}' | Sentiment: {sample_sentiments[i]}")
# Out:
#                                         comment_text sentiment
# 0                  Logan Paul it's yo big day ‼️‼️‼️   neutral
# 1  I've been following you from the start of your...   neutral
# 2                 Say hi to Kong and maverick for me   neutral
# 3                                MY FAN . attendance  positive
# 4                                         trending 😉   neutral
#
# Sample Comment Sentiments:
# Comment: 'I love this product!' | Sentiment: positive
# Comment: 'This is terrible.' | Sentiment: negative
# Comment: 'It's okay, I guess.' | Sentiment: positive
